# %% [markdown]
# <a href="https://colab.research.google.com/github/Upendra11223/CC-attack/blob/master/opencv_faster_rcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DatumLearning/Faster_RCNN_Opencv.git
# Out:
# Cloning into 'Faster_RCNN_Opencv'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 18 (delta 3), reused 0 (delta 0), pack-reused 8 (from 1)
# Receiving objects: 100% (18/18), 57.35 MiB | 26.84 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import numpy as np
import random
import time
import cv2
import os
from google.colab.patches import cv2_imshow

# %%
coco_names = ["person" , "bicycle" , "car" , "motorcycle" , "airplane" , "bus" , "train" , "truck" , "boat" , "traffic light" , "fire hydrant" , "street sign" , "stop sign" , "parking meter" , "bench" , "bird" , "cat" , "dog" , "horse" , "sheep" , "cow" , "elephant" , "bear" , "zebra" , "giraffe" , "hat" , "backpack" , "umbrella" , "shoe" , "eye glasses" , "handbag" , "tie" , "suitcase" ,
"frisbee" , "skis" , "snowboard" , "sports ball" , "kite" , "baseball bat" ,
"baseball glove" , "skateboard" , "surfboard" , "tennis racket" , "bottle" ,
"plate" , "wine glass" , "cup" , "fork" , "knife" , "spoon" , "bowl" ,
"banana" , "apple" , "sandwich" , "orange" , "broccoli" , "carrot" , "hot dog" ,
"pizza" , "donut" , "cake" , "chair" , "couch" , "potted plant" , "bed" ,
"mirror" , "dining table" , "window" , "desk" , "toilet" , "door" , "tv" ,
"laptop" , "mouse" , "remote" , "keyboard" , "cell phone" , "microwave" ,
"oven" , "toaster" , "sink" , "refrigerator" , "blender" , "book" ,
"clock" , "vase" , "scissors" , "teddy bear" , "hair drier" , "toothbrush" , "hair brush"]

# %%
weightsPath = "/content/Faster_RCNN_Opencv/frozen_inference_graph.pb"
configPath = "/content/Faster_RCNN_Opencv/mask_rcnn_inception_v2_coco_2018_01_28.pbtxt"

# %%
net = cv2.dnn.readNetFromTensorflow(weightsPath, configPath)
net.setInput(blob)
boxes = net.forward(["detection_out_final"])
output = boxes[0].squeeze()
num = np.argwhere(output[: , 2] > 0.8).shape[0]

# %%
image = cv2.imread("/content/cat.webp")
(H, W) = image.shape[:2]

# %%
blob = cv2.dnn.blobFromImage(image, swapRB=True, crop=False)

# %%
net.setInput(blob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-3268543902.py in <cell line: 0>()
# ----> 1 net.setInput(blob)
#
# NameError: name 'net' is not defined

# %%
boxes = net.forward(["detection_out_final"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-1888512773.py in <cell line: 0>()
# ----> 1 boxes = net.forward(["detection_out_final"])
#
# NameError: name 'net' is not defined

# %%
output = boxes[0].squeeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-44112573.py in <cell line: 0>()
# ----> 1 output = boxes[0].squeeze()
#
# NameError: name 'boxes' is not defined

# %%
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-11-2415424161.py in <cell line: 0>()
# ----> 1 output
#
# NameError: name 'output' is not defined

# %%
output[: , 2][:5] , output[: , 1][:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-12-2505305154.py in <cell line: 0>()
# ----> 1 output[: , 2][:5] , output[: , 1][:5]
#
# NameError: name 'output' is not defined

# %%
output[: , 3:][:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-3096727032.py in <cell line: 0>()
# ----> 1 output[: , 3:][:5]
#
# NameError: name 'output' is not defined

# %%
num = np.argwhere(output[: , 2] > 0.8).shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-2929116902.py in <cell line: 0>()
# ----> 1 num = np.argwhere(output[: , 2] > 0.8).shape[0]
#
# NameError: name 'output' is not defined

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
# Ensure image_path is defined and load the image
image_path = "/content/cat.webp" # Make sure this path is correct
img = cv2.imread(image_path) # Load the image again to draw on it

# Check if the image was loaded successfully
if img is None:
    print(f"Error: Could not load image from {image_path}")
else:
    (H, W) = img.shape[:2] # Get image dimensions again in case they are needed

    for i in range(num):
        x1n , y1n , x2n , y2n = output[i , 3:]
        x1 = int(x1n * W)
        y1 = int(y1n * H)
        x2 = int(x2n * W)
        y2 = int(y2n * H)
        img = cv2.rectangle(img , (x1 , y1) , (x2 , y2) , (0 , 255 , 0) , 3)
        class_name = coco_names[int(output[i , 1])]
        img = cv2.putText(img , class_name , (x1 , y1 - 10) , font , 0.5 ,
                          (255 , 0 , 0) , 1 , cv2.LINE_AA)

    # Display the image after drawing on it
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200>

# %%
2
